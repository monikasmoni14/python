# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
def my_function():
    x = 5
    print(x)

# %%
my_function()
# Out:
# 5

# %%
x=input("enter the x:")
if (x == 9):
    print("x is 10")
else:
    print("x is not 10")
# Out:
# enter the x: 10
# x is not 10

# %%
number = [5, 3, 8, 2]
print("number",number)
# Out:
# number [5, 3, 8, 2]

# %%
def square(n):
    s= n**n
    print("square(n)",s)

# %%
n=int(input("enter the number:"))
# Out:
# enter the number: 5

# %%
square(n)
# Out:
# square(n) 3125
