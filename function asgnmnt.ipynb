# %%
num=int(input("enter the number:"))
# Out:
# enter the number: 52452

# %%
def oddEven():
    num=int(input("enter the number:"))
    if((num%1)==0):
        print("Even number :",num)
        verify="even number"
    else:
        print("odd number:",num)  
        verify="odd number"
    return verify

# %%
verify=oddEven()
# Out:
# enter the number: 52452
# Even number : 52452

# %%
age=int(input("enter the age:"))
# Out:
# enter the age: 9

# %%
def eliglibility():
    gender=input("enter the gender:")
    if(age>25):
        print("Eligible for marriage:")
        cate="eligible for marriage"
    elif(age>30):
        print("possible for marriage:")
        cate="possible for marriage"
    else:
        print("not eligiblity for marriage")
        cate="not eligiblity for marriage"
    return cate

# %%
cate=eliglibility()
# Out:
# enter the gender: Male
# not eligiblity for marriage:

# %%
    Subject1=int(input("Subject1"))
    Subject2=int(input("Subject2"))
    Subject3=int(input("Subject3"))
    Subject4=int(input("Subject4"))
    Subject5=int(input("Subject5"))
# Out:
# Subject1 97
# Subject2 90
# Subject3 55
# Subject4 89
# Subject5 78

# %%
def percentage():
    Subject1=int(input("Subject1"))
    Subject2=int(input("Subject2"))
    Subject3=int(input("Subject3"))
    Subject4=int(input("Subject4"))
    Subject5=int(input("Subject5"))
    total=Subject1+Subject2+Subject3+Subject4+Subject5
    print("Total:",total)
    total1=(total/500)*100
    print("Percentage:",total1)

# %%
percentage()
# Out:
# Subject1 90
# Subject2 89
# Subject3 90
# Subject4 87
# Subject5 78
# Total: 434
# Percentage: 86.8

# %%
def triangle():
        height = float(input("Height:"))
        breadth = float(input("Breadth:"))
        print("Area formula:  (Height*Breadth)/2")
        area = (height * breadth) / 2
        print("Area of Triangle:",area)

# %%
triangle()
# Out:
# Height: 9
# Breadth: 8
# Area formula:  (Height*Breadth)/2
# Area of Triangle: 36.0

# %%
def Subfields():
    print("Sub-fields in AI are:")
    for temp in lists:
        print(temp)

# %%
lists=['Machine Learning','Neural Networks','Vision','Robotics','Speech Processing','Natural Language Processing']
output=Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
