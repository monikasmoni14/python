# %%
num1=int(input("num1="))
# Out:
# num1= 10

# %%
num2=int(input(" num2="))
# Out:
#  num2= 30

# %%
add=num1+num2
print(add)
# Out:
# 40

# %%
BMI=int(input("enter the BMI:"))
# Out:
# enter the BMI: 34

# %%
if(BMI<18):
    print("normal weight")
else:
    print("overweight")
# Out:
# overweight
