# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name=(input("enter the institution name:"))
print(name)
# Out:
# enter the institution name: hope ai
# hope ai

# %%
name=input("enter your name:")
age=20
college=("ngce")
degree=("b.tech ai")
print("enter your age:",age)
print("enter your college name:",college)
print("enter your degree:",degree)
# Out:
# enter your name: monika s
# enter your age: 20
# enter your college name: ngce
# enter your degree: b.tech ai

# %%
num1=int(input("a="))
num2=int(input("b="))
add=num1+num2
print("addition=",add)
# Out:
# a= 43
# b= 34
# addition= 77

# %%
num1=int(input("a="))
num2=int(input("b="))
sub=num1-num2
print("subtraction=",sub)
# Out:
# a= 43
# b= 34
# subtraction= 9

# %%
num1=int(input("a="))
num2=int(input("b="))
mul=num1*num2
print("multiplication=",mul)
# Out:
# a= 63
# b= 97
# multiplication= 6111

# %%
num1=int(input("a="))
num2=int(input("b="))
div=num1/num2
print("division=",div)
# Out:
# a= 76
# b= 31
# division= 2.4516129032258065

# %%
num1=int(input("a="))
num2=int(input("b="))
floor=num1//num2
print("floordivision=",floor)
# Out:
# a= 76
# b= 31
# floordivision= 2

# %%
num1=int(input("a="))
num2=int(input("b="))
mod=num1%num2
print("moduls=",mod)
# Out:
# a= 76
# b= 31
# moduls= 14

# %%
num1=int(input("a="))
num2=int(input("b="))
pow=num1^num2
print("power=",pow)
# Out:
# a= 4
# b= 4
# power= 0
